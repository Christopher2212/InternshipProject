# %%
import pandas as pd
from pyvis.network import Network 
import numpy as np 

PI = 3.141592653589793238    
def makeNetwork(nodeListName, edgeListName, nodeMapName):
    #init the network
    
    nodeList = pd.read_csv(nodeListName)
    edgeList = pd.read_csv(edgeListName)
    print(nodeList.to_string())
    print(edgeList.to_string())
    nodeNetwork = Network()

    for row in nodeList.iterrows():
        #add nodes to the list
        print(row[1]["id"])
        print(row[1]["name"])
        nodeNetwork.add_node(n_id = row[1]["id"], label = row[1]["name"])
        
    for row in edgeList.iterrows():
        lat1 = (nodeList.iloc[row[1]["from"]-1]["latitude"])/(180/PI) 
        lat2 = (nodeList.iloc[row[1]["to"]-1]["latitude"])/(180/PI)
        long1 = (nodeList.iloc[row[1]["from"]-1]["longitude"])/(180/PI)
        long2 = (nodeList.iloc[row[1]["to"]-1]["longitude"])/(180/PI)
        
        #lat2 = nodeList["latitude"].loc[nodeList.index[row[1]["to"]]]/(180/PI)
        #long1 = nodeList["longitude"].loc[nodeList.index[row[1]["from"]]]/(180/PI)
        #long2 = nodeList["longitude"].loc[nodeList.index[row[1]["to"]]/(180/PI)
    
        #TODO: Make sure to double check on how sin cos and arccos take in degrees or radians
        dist = 6378.8 * np.arccos(np.sin(lat1) * np.sin(lat2) + np.cos(lat1) * np.cos(lat2) * np.cos(long2 - long1))
        nodeNetwork.add_edge(row[1]["from"], row[1]["to"], weight = dist, title = dist)
        
    nodeNetwork.barnes_hut()
    nodeNetwork.save_graph(nodeMapName)
    nodeNetwork.show(nodeMapName)
makeNetwork("Other\EdgeandVertListsCSV\BangkokVert.csv","Other/EdgeandVertListsCSV/BangkokEdge.csv","BangNodeMap.html")
# Out:
#     id                      name   latitude   longitude
# 0    1                    Samyan  13.732350  100.529993
# 1    2                    Si Lom  13.729250  100.536545
# 2    3                  Lumphini  13.725764  100.545666
# 3    4               Khlong Toei  13.722299  100.553915
# 4    5         Queen Sirikit NCC  13.723152  100.560102
# 5    6                 Sukhumvit  13.738527  100.561447
# 6    7               Phetchaburi  13.748704  100.563124
# 7    8                Phra Ram 9  13.757922  100.565568
# 8    9  Thailand Cultural Centre  13.766300  100.570260
# 9   10               Huai Khwang  13.778514  100.573645
# 10  11                 Sutthisan  13.789742  100.574201
# 11  12            Ratchadaphisek  13.799149  100.574613
# 12  13                 Lat Phrao  13.806102  100.573652
# 13  14             Phahon Yothin  13.814237  100.560148
# 14  15            Chatuchak Park  13.802456  100.553738
# 15  16              Saphan Khwai  13.793766  100.549710
# 16  17                       Ari  13.779689  100.544646
# 17  18                 Sanam Peo  13.772642  100.542103
# 18  19          Victory Monument  13.762793  100.537085
# 19  20                Phaya Thai  13.756923  100.533803
# 20  21               Ratchathewi  13.751988  100.531577
# 21  22                      Siam  13.745610  100.534120
# 22  23                  Chit Lom  13.744094  100.543065
# 23  24               Phloen Chit  13.743044  100.548974
# 24  25                      Nana  13.740523  100.555434
# 25  26                      Asok  13.737059  100.560306
# 26  27                 Phayathai  13.756738  100.534842
# 27  28              Ratchaprarop  13.755022  100.542122
# 28  29                  Makkasan  13.750836  100.561337
# 29  30              Ramkhamhaeng  13.742999  100.600150
# 30  31                   Hua Mak  13.738150  100.640185
# 31  32          National Stadium  13.746473  100.529073
# 32  33               Ratchadamri  13.739450  100.539440
# 33  34    Sala Daeng BTS Station  13.728478  100.534114
# 34  35               Chong Nonsi  13.723730  100.529430
#     from  to   line linecolor
# 0      1   2   Blue   #0000FF
# 1      2   3   Blue   #0000FF
# 2      3   4   Blue   #0000FF
# 3      4   5   Blue   #0000FF
# 4      5   6   Blue   #0000FF
# 5      6   7   Blue   #0000FF
# 6      7   8   Blue   #0000FF
# 7      8   9   Blue   #0000FF
# 8      9  10   Blue   #0000FF
# 9     10  11   Blue   #0000FF
# 10    11  12   Blue   #0000FF
# 11    12  13   Blue   #0000FF
# 12    13  14   Blue   #0000FF
# 13    14  15   Blue   #0000FF
# 14    15  16   Blue   #0000FF
# 15    16  17  Green   #00FF00
# 16    17  18  Green   #00FF00
# 17    18  19  Green   #00FF00
# 18    19  20  Green   #00FF00
# 19    20  21  Green   #00FF00
# 20    21  22  Green   #00FF00
# 21    22  23  Green   #00FF00
# 22    23  24  Green   #00FF00
# 23    24  25  Green   #00FF00
# 24    25  26  Green   #00FF00
# 25    26   6  Green   #00FF00
# 26    20  27    Red   #FF0000
# 27    27  28    Red   #FF0000
# 28    28  29    Red   #FF0000
# 29    29   7    Red   #FF0000
# 30    29  30    Red   #FF0000
# 31    30  31    Red   #FF0000
# 32    32  22    Red   #FF0000
# 33    22  33    Red   #FF0000
# 34    33  34    Red   #FF0000
# 35    34   2    Red   #FF0000
# 36    34  35    Red   #FF0000
# 1
# Samyan
# 2
# Si Lom
# 3
# Lumphini
# 4
# Khlong Toei
# 5
# Queen Sirikit NCC
# 6
# Sukhumvit
# 7
# Phetchaburi
# 8
# Phra Ram 9
# 9
# Thailand Cultural Centre
# 10
# Huai Khwang
# 11
# Sutthisan
# 12
# Ratchadaphisek
# 13
# Lat Phrao
# 14
# Phahon Yothin
# 15
# Chatuchak Park
# 16
# Saphan Khwai
# 17
# Ari
# 18
# Sanam Peo
# 19
# Victory Monument
# 20
# Phaya Thai
# 21
# Ratchathewi
# 22
# Siam
# 23
# Chit Lom
# 24
# Phloen Chit
# 25
# Nana
# 26
# Asok
# 27
# Phayathai
# 28
# Ratchaprarop
# 29
# Makkasan
# 30
# Ramkhamhaeng
# 31
# Hua Mak
# 32
# National Stadium
# 33
# Ratchadamri
# 34
# Sala Daeng BTS Station
# 35
# Chong Nonsi
